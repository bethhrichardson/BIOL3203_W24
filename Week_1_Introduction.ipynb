# %% [markdown]
# #**WEEK 1**

# %% [markdown]
# #Part 1. Logging onto the server and setting up for the semester.
#
# If you're reading this, congratulations. You've successfully a) located Dr. Richardson's GitHub respository, b) located the correct file for Lab 1, and c) opened the Jupyter notebook on your own Google Drive Colaboratory.
#
# If you've never used this format before, it's called a Jupyter Notebook and it's the mechanism by which we'll be storing (and grading) your code for the semester. The labs themselves are adapted from the first four chapters of the open-source textbook Applied Bioinformatics by David A. Hendrix, which can be found [here](https://https://open.oregonstate.education/appliedbioinformatics/). I strongly suggest reading each week's chapter before the lab to get an idea of what you'll be working on. In this course, we will be using two(ish) programming languages; the command-line interface and Python, both of which are found in this textbook. We will also be using a specific Python library called "BioPython", which contains a bunch of pre-defined object classes and functions which make working with biological data formats in Python a lot easier.
#
# For the first half of the semester, all your work will be completed within the Jupyter notebook interface. For the second half of the semester, you will be interfacing with a remote server run by the Mathematics and Computing department which you will access through the terminal of your computer.

# %%
##This is what a codeblock looks like in Jupyter Notebooks. This section in green is a comment, denoted by the hastags to the left.
##This means I can write anything I like and the computer won't interpret it as a programme.
##Try adding a comment under here! Maybe a nice compliment to Brian, since he'll read it later.

##These blocks are also how we'll run code. There's an example programme written below; if you click on the play button to the left, it will run.
##The result of the programme will appear in a box under this code block.

print("Hello world!")

##Now it's your turn! Write a Python command to print whatever you like. Make sure you run it to check it works!

# %% [markdown]
# The first task for the semester is to ensure that you have access to your account on the server. Even though we won't actually be using the server until after Reading Week, checking we have access in advance will ensure that we have a chance to fix any technical issues that might arise.
#
# For this part of the class, you will follow the instructions given by a) Brian and b) the handout from IT which has been provided for you.

# %%
#Since there's nothing for me to do at this point while you log into the server, here's a piece of Python code that counts to 10.
#If you've already finished the logging-in task and you want something to do, feel free to click the play button a bunch of times.

import time

for i in range(1, 11):
        print(i)
        time.sleep(1)

# %% [markdown]
# #Part 2: BashCrawl
#
# This lab is a lot shorter than the others, because for a lot of you this might be the first time you've ever interacted with a computer in a non-mousey way and that can be very intimidating. The second task for today once you have situated yourself within the Jupyter Notebook environment, have exhausted your questions on how the format of the lab will work, and successfully logged into your MaCo server account is to practice your command line skills using BashCrawl, an interactive Bash tutorial and fantasy RPG which can be found [here](https://gitlab.com/slackermedia/bashcrawl). You can use the text box below to take note of any useful bash commands and / or tips that you learn from this.

# %% [markdown]
# 1.
# 2.
# 3.

# %% [markdown]
# That's all for today! Make sure you save any changes you've made to the notebook in your shared folder.

# %% [markdown]
# © Elisabeth Richardson, 2023. Adapted from Applied Bioinformatics by David A. Hendricks under a [CC-by-4.0 license](https://https://creativecommons.org/licenses/by/4.0/) and shared under same.
