# %% [markdown]
# #**WEEK 3**
#
# This week we'll be working through an adapted version of Exercises 4-5 and Lab 2 from Applied Bioinformatics.
#
# First, we have to install BioPython again, since this is a new notebook. You can do that by running the code block below.

# %%
##Install BioPython in Jupyter Notebook
# %pip install biopython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 29.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# #Part 1: FastQ
# First, make sure that you've read Section 1.3.2 of the textbook (FastQ). If you haven't read it, do that now.
#
# We're going to look at some fastq data, but before that we need to download it from the Applied Bioinformatics teaching server. We're going to do that using wget, which is a command-line utility. In Jupyter notebooks, you run it using the following command:
#
#
#
# ```
# !wget <full link to resource>
# ```
#
# The URL for the data file we want is:
#
#
#
# ```
# https://hendrixlab.cgrb.oregonstate.edu/teaching/reads.fastq
# ```
#
# Try running the code block below, then check your directory.

# %%
# !wget https://hendrixlab.cgrb.oregonstate.edu/teaching/reads.fastq
# Out:
# --2023-12-01 22:37:54--  https://hendrixlab.cgrb.oregonstate.edu/teaching/reads.fastq
# Resolving hendrixlab.cgrb.oregonstate.edu (hendrixlab.cgrb.oregonstate.edu)... 128.193.83.38
# Connecting to hendrixlab.cgrb.oregonstate.edu (hendrixlab.cgrb.oregonstate.edu)|128.193.83.38|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2595548 (2.5M)
# Saving to: ‘reads.fastq’
#
# reads.fastq         100%[===================>]   2.47M  3.90MB/s    in 0.6s
#
# 2023-12-01 22:37:55 (3.90 MB/s) - ‘reads.fastq’ saved [2595548/2595548]

# %% [markdown]
# Now let's import your data as a variable so we can work with it in BioPython.

# %%
from Bio import SeqIO
fastqFile = "reads.fastq" # FASTQ file name
data = SeqIO.parse(fastqFile,"fastq") # parse the FASTQ file

# %% [markdown]
# The mechanism for how Phred scores are calculated is discussed in detail in the textbook. If you'd like to try running any of the commands in this section, you can use the code block below. Make sure you understand what a Phred score is - this will come up again later!

# %%
##Your code here. Try pasting in some commands from the textbook if you want to see what they do in practice.

# %% [markdown]
# Now it's time for Exercise 4 (with some extra bits)
#
# >1. What probability of error corresponds to the following quality score characters:
# >
# >- !
# >- A
# >- a
# >- %
# >
# >Are these good or bad scores? How do you know?
#
# 2. Do Phred scores get better or worse as a sequence extends? How does this correspond to the likelihood of error?

# %% [markdown]
# You can use this text box to write your answers.

# %% [markdown]
# #Part 2: Applied Bioinformatics Lab 2
#
# First, use the wget command to download the following script:
#
# ````https://hendrixlab.cgrb.oregonstate.edu/teaching/printAverageQualityScores.py````

# %%
##Your code here

# %% [markdown]
# Next, let's count the number of lines in the fastq file. Given the result, how many reads do you think are contained in this file? Why?

# %%
# !wc -l reads.fastq
# Out:
# 40000 reads.fastq

# %% [markdown]
# \---------------------------
# You can add your answer in this text box.
# \---------------------------

# %% [markdown]
# Next, let's check what happens when you run the script without any input.

# %%
# !python printAverageQualityScores.py

# %% [markdown]
# Looks like something's missing: let's add the reads.fastq file and see what happens.

# %%
# !python printAverageQualityScores.py reads.fastq

# %% [markdown]
# The script will create a file called quality.pdf, which is saved in your directory. How does this plot look? What does this say about errors in sequencing data?

# %% [markdown]
# \---------------------------
# You can add your answer in this text box.
# \---------------------------

# %% [markdown]
# We're going to leave the Lab 2 tutorial here, but there are many tools one can use to trim a FastQ file based on quality parameters. My personal favourite is FastQC, which you can learn more about [here.](https://www.bioinformatics.babraham.ac.uk/projects/fastqc/)
#
# Compare the report outputs from "Good Illumina Data" and "Bad Illumina data". in the Sample Reports section. For each of the eleven panels, compare and contrast the results. How does the output tell you one is a "good" fastq and one is a "bad" fastq?

# %% [markdown]
# \---------------------------
# You can add your answer in this text box.
# \---------------------------

# %% [markdown]
# © Elisabeth Richardson, 2023. Adapted from Applied Bioinformatics by David A. Hendricks under a [CC-by-4.0 license](https://https://creativecommons.org/licenses/by/4.0/) and shared under same.
